# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, average_precision_score
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv('dataset/creditcard.csv')
x = data.drop('Class', axis=1)
y = data['Class']
x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size=0.2, stratify=y)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.2, stratify=y_train_val)

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01],
    'n_estimators': [100, 200,500,800]
}

grid = GridSearchCV(XGBClassifier(tree_method='hist', device='cuda:1', verbosity=0,), param_grid, scoring='average_precision', cv=3)
grid.fit(x_train, y_train)

print(f"best parameters: {grid.best_params_}")
# Out:
# best parameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 800}

# %%
ratio = len(y_train[y_train==0]) / len(y_train[y_train==1])

model = XGBClassifier(
    n_estimators=500,
    max_depth=5,
    learning_rate=0.1,
    scale_pos_weight=ratio,
    eval_metric='aucpr',
    early_stopping_rounds=50
)

model.fit(
    x_train,
    y_train,
    eval_set=[(x_val, y_val)],
    verbose=True
)
# Out:
# [0]	validation_0-aucpr:0.45293
# [1]	validation_0-aucpr:0.64651
# [2]	validation_0-aucpr:0.64187
# [3]	validation_0-aucpr:0.63923
# [4]	validation_0-aucpr:0.64703
# [5]	validation_0-aucpr:0.64950
# [6]	validation_0-aucpr:0.66289
# [7]	validation_0-aucpr:0.66210
# [8]	validation_0-aucpr:0.66401
# [9]	validation_0-aucpr:0.70131
# [10]	validation_0-aucpr:0.70001
# [11]	validation_0-aucpr:0.70152
# [12]	validation_0-aucpr:0.70250
# [13]	validation_0-aucpr:0.70232
# [14]	validation_0-aucpr:0.72307
# [15]	validation_0-aucpr:0.72463
# [16]	validation_0-aucpr:0.72497
# [17]	validation_0-aucpr:0.72579
# [18]	validation_0-aucpr:0.72713
# [19]	validation_0-aucpr:0.73676
# [20]	validation_0-aucpr:0.73712
# [21]	validation_0-aucpr:0.73543
# [22]	validation_0-aucpr:0.73396
# [23]	validation_0-aucpr:0.73208
# [24]	validation_0-aucpr:0.73326
# [25]	validation_0-aucpr:0.73302
# [26]	validation_0-aucpr:0.73341
# [27]	validation_0-aucpr:0.73307
# [28]	validation_0-aucpr:0.73219
# [29]	validation_0-aucpr:0.73248
# [30]	validation_0-aucpr:0.73196
# [31]	validation_0-aucpr:0.73136
# [32]	validation_0-aucpr:0.73297
# [33]	validation_0-aucpr:0.73209
# [34]	validation_0-aucpr:0.73465
# [35]	validation_0-aucpr:0.73402
# [36]	validation_0-aucpr:0.73372
# [37]	validation_0-aucpr:0.73209
# [38]	validation_0-aucpr:0.76036
# [39]	validation_0-aucpr:0.74117
# [40]	validation_0-aucpr:0.73047
# [41]	validation_0-aucpr:0.73062
# [42]	validation_0-aucpr:0.72928
# [43]	validation_0-aucpr:0.73097
# [44]	validation_0-aucpr:0.72987
# [45]	validation_0-aucpr:0.73091
# [46]	validation_0-aucpr:0.72932
# [47]	validation_0-aucpr:0.72845
# [48]	validation_0-aucpr:0.73987
# [49]	validation_0-aucpr:0.74191
# [50]	validation_0-aucpr:0.74772
# [51]	validation_0-aucpr:0.75092
# [52]	validation_0-aucpr:0.75222
# [53]	validation_0-aucpr:0.75372
# [54]	validation_0-aucpr:0.75373
# [55]	validation_0-aucpr:0.75282
# [56]	validation_0-aucpr:0.75061
# [57]	validation_0-aucpr:0.75031
# [58]	validation_0-aucpr:0.75255
# [59]	validation_0-aucpr:0.75330
# [60]	validation_0-aucpr:0.75534
# [61]	validation_0-aucpr:0.75352
# [62]	validation_0-aucpr:0.75368
# [63]	validation_0-aucpr:0.75364
# [64]	validation_0-aucpr:0.75340
# [65]	validation_0-aucpr:0.74852
# [66]	validation_0-aucpr:0.75691
# [67]	validation_0-aucpr:0.76149
# [68]	validation_0-aucpr:0.76137
# [69]	validation_0-aucpr:0.75908
# [70]	validation_0-aucpr:0.76183
# [71]	validation_0-aucpr:0.76004
# [72]	validation_0-aucpr:0.77358
# [73]	validation_0-aucpr:0.77254
# [74]	validation_0-aucpr:0.77480
# [75]	validation_0-aucpr:0.77110
# [76]	validation_0-aucpr:0.77417
# [77]	validation_0-aucpr:0.76938
# [78]	validation_0-aucpr:0.77484
# [79]	validation_0-aucpr:0.77640
# [80]	validation_0-aucpr:0.77888
# [81]	validation_0-aucpr:0.77791
# [82]	validation_0-aucpr:0.77906
# [83]	validation_0-aucpr:0.77745
# [84]	validation_0-aucpr:0.77840
# [85]	validation_0-aucpr:0.77725
# [86]	validation_0-aucpr:0.77741
# [87]	validation_0-aucpr:0.78015
# [88]	validation_0-aucpr:0.77865
# [89]	validation_0-aucpr:0.78005
# [90]	validation_0-aucpr:0.77960
# [91]	validation_0-aucpr:0.77814
# [92]	validation_0-aucpr:0.78236
# [93]	validation_0-aucpr:0.78104
# [94]	validation_0-aucpr:0.77750
# [95]	validation_0-aucpr:0.78150
# [96]	validation_0-aucpr:0.78284
# [97]	validation_0-aucpr:0.79123
# [98]	validation_0-aucpr:0.79068
# [99]	validation_0-aucpr:0.78875
# [100]	validation_0-aucpr:0.79036
# [101]	validation_0-aucpr:0.78909
# [102]	validation_0-aucpr:0.79163
# [103]	validation_0-aucpr:0.79379
# [104]	validation_0-aucpr:0.79495
# [105]	validation_0-aucpr:0.79295
# [106]	validation_0-aucpr:0.79259
# [107]	validation_0-aucpr:0.79195
# [108]	validation_0-aucpr:0.79248
# [109]	validation_0-aucpr:0.79222
# [110]	validation_0-aucpr:0.79143
# [111]	validation_0-aucpr:0.78965
# [112]	validation_0-aucpr:0.78896
# [113]	validation_0-aucpr:0.78868
# [114]	validation_0-aucpr:0.79055
# [115]	validation_0-aucpr:0.79226
# [116]	validation_0-aucpr:0.79300
# [117]	validation_0-aucpr:0.79299
# [118]	validation_0-aucpr:0.79252
# [119]	validation_0-aucpr:0.79246
# [120]	validation_0-aucpr:0.79258
# [121]	validation_0-aucpr:0.79506
# [122]	validation_0-aucpr:0.79640
# [123]	validation_0-aucpr:0.79481
# [124]	validation_0-aucpr:0.79527
# [125]	validation_0-aucpr:0.79479
# [126]	validation_0-aucpr:0.79466
# [127]	validation_0-aucpr:0.79499
# [128]	validation_0-aucpr:0.79397
# [129]	validation_0-aucpr:0.79421
# [130]	validation_0-aucpr:0.79423
# [131]	validation_0-aucpr:0.79550
# [132]	validation_0-aucpr:0.79556
# [133]	validation_0-aucpr:0.79680
# [134]	validation_0-aucpr:0.79710
# [135]	validation_0-aucpr:0.79715
# [136]	validation_0-aucpr:0.79657
# [137]	validation_0-aucpr:0.79647
# [138]	validation_0-aucpr:0.79605
# [139]	validation_0-aucpr:0.79563
# [140]	validation_0-aucpr:0.79722
# [141]	validation_0-aucpr:0.79750
# [142]	validation_0-aucpr:0.79620
# [143]	validation_0-aucpr:0.79541
# [144]	validation_0-aucpr:0.79659
# [145]	validation_0-aucpr:0.79745
# [146]	validation_0-aucpr:0.80336
# [147]	validation_0-aucpr:0.80276
# [148]	validation_0-aucpr:0.80001
# [149]	validation_0-aucpr:0.79950
# [150]	validation_0-aucpr:0.80069
# [151]	validation_0-aucpr:0.80207
# [152]	validation_0-aucpr:0.80281
# [153]	validation_0-aucpr:0.80231
# [154]	validation_0-aucpr:0.80269
# [155]	validation_0-aucpr:0.80278
# [156]	validation_0-aucpr:0.80313
# [157]	validation_0-aucpr:0.80373
# [158]	validation_0-aucpr:0.80487
# [159]	validation_0-aucpr:0.80648
# [160]	validation_0-aucpr:0.80729
# [161]	validation_0-aucpr:0.81001
# [162]	validation_0-aucpr:0.81027
# [163]	validation_0-aucpr:0.80940
# [164]	validation_0-aucpr:0.81015
# [165]	validation_0-aucpr:0.81136
# [166]	validation_0-aucpr:0.81258
# [167]	validation_0-aucpr:0.81234
# [168]	validation_0-aucpr:0.81301
# [169]	validation_0-aucpr:0.81308
# [170]	validation_0-aucpr:0.81258
# [171]	validation_0-aucpr:0.81308
# [172]	validation_0-aucpr:0.81336
# [173]	validation_0-aucpr:0.81340
# [174]	validation_0-aucpr:0.81374
# [175]	validation_0-aucpr:0.81522
# [176]	validation_0-aucpr:0.81575
# [177]	validation_0-aucpr:0.81737
# [178]	validation_0-aucpr:0.81651
# [179]	validation_0-aucpr:0.81742
# [180]	validation_0-aucpr:0.81622
# [181]	validation_0-aucpr:0.81722
# [182]	validation_0-aucpr:0.81703
# [183]	validation_0-aucpr:0.81686
# [184]	validation_0-aucpr:0.81847
# [185]	validation_0-aucpr:0.81829
# [186]	validation_0-aucpr:0.81909
# [187]	validation_0-aucpr:0.81948
# [188]	validation_0-aucpr:0.81957
# [189]	validation_0-aucpr:0.81940
# [190]	validation_0-aucpr:0.81936
# [191]	validation_0-aucpr:0.82008
# [192]	validation_0-aucpr:0.82085
# [193]	validation_0-aucpr:0.82074
# [194]	validation_0-aucpr:0.82151
# [195]	validation_0-aucpr:0.82107
# [196]	validation_0-aucpr:0.82135
# [197]	validation_0-aucpr:0.82181
# [198]	validation_0-aucpr:0.82212
# [199]	validation_0-aucpr:0.82169
# [200]	validation_0-aucpr:0.82177
# [201]	validation_0-aucpr:0.82245
# [202]	validation_0-aucpr:0.82241
# [203]	validation_0-aucpr:0.82352
# [204]	validation_0-aucpr:0.82373
# [205]	validation_0-aucpr:0.82359
# [206]	validation_0-aucpr:0.82375
# [207]	validation_0-aucpr:0.82420
# [208]	validation_0-aucpr:0.82430
# [209]	validation_0-aucpr:0.82413
# [210]	validation_0-aucpr:0.82480
# [211]	validation_0-aucpr:0.82506
# [212]	validation_0-aucpr:0.82550
# [213]	validation_0-aucpr:0.82535
# [214]	validation_0-aucpr:0.82530
# [215]	validation_0-aucpr:0.82616
# [216]	validation_0-aucpr:0.82561
# [217]	validation_0-aucpr:0.82593
# [218]	validation_0-aucpr:0.82594
# [219]	validation_0-aucpr:0.82679
# [220]	validation_0-aucpr:0.82683
# [221]	validation_0-aucpr:0.82694
# [222]	validation_0-aucpr:0.82671
# [223]	validation_0-aucpr:0.82676
# [224]	validation_0-aucpr:0.82664
# [225]	validation_0-aucpr:0.82672
# [226]	validation_0-aucpr:0.82634
# [227]	validation_0-aucpr:0.82593
# [228]	validation_0-aucpr:0.82635
# [229]	validation_0-aucpr:0.82697
# [230]	validation_0-aucpr:0.82677
# [231]	validation_0-aucpr:0.82717
# [232]	validation_0-aucpr:0.82657
# [233]	validation_0-aucpr:0.82700
# [234]	validation_0-aucpr:0.82629
# [235]	validation_0-aucpr:0.82685
# [236]	validation_0-aucpr:0.82574
# [237]	validation_0-aucpr:0.82610
# [238]	validation_0-aucpr:0.82669
# [239]	validation_0-aucpr:0.82684
# [240]	validation_0-aucpr:0.82674
# [241]	validation_0-aucpr:0.82678
# [242]	validation_0-aucpr:0.82673
# [243]	validation_0-aucpr:0.82675
# [244]	validation_0-aucpr:0.82671
# [245]	validation_0-aucpr:0.82714
# [246]	validation_0-aucpr:0.82713
# [247]	validation_0-aucpr:0.82728
# [248]	validation_0-aucpr:0.82717
# [249]	validation_0-aucpr:0.82679
# [250]	validation_0-aucpr:0.82672
# [251]	validation_0-aucpr:0.82691
# [252]	validation_0-aucpr:0.82728
# [253]	validation_0-aucpr:0.82713
# [254]	validation_0-aucpr:0.82711
# [255]	validation_0-aucpr:0.82682
# [256]	validation_0-aucpr:0.82776
# [257]	validation_0-aucpr:0.82773
# [258]	validation_0-aucpr:0.82736
# [259]	validation_0-aucpr:0.82750
# [260]	validation_0-aucpr:0.82716
# [261]	validation_0-aucpr:0.82703
# [262]	validation_0-aucpr:0.82708
# [263]	validation_0-aucpr:0.82727
# [264]	validation_0-aucpr:0.82777
# [265]	validation_0-aucpr:0.82754
# [266]	validation_0-aucpr:0.82797
# [267]	validation_0-aucpr:0.82817
# [268]	validation_0-aucpr:0.82849
# [269]	validation_0-aucpr:0.82890
# [270]	validation_0-aucpr:0.82875
# [271]	validation_0-aucpr:0.82836
# [272]	validation_0-aucpr:0.82876
# [273]	validation_0-aucpr:0.82905
# [274]	validation_0-aucpr:0.82909
# [275]	validation_0-aucpr:0.82887
# [276]	validation_0-aucpr:0.82890
# [277]	validation_0-aucpr:0.82859
# [278]	validation_0-aucpr:0.82920
# [279]	validation_0-aucpr:0.82897
# [280]	validation_0-aucpr:0.82875
# [281]	validation_0-aucpr:0.82931
# [282]	validation_0-aucpr:0.82904
# [283]	validation_0-aucpr:0.82878
# [284]	validation_0-aucpr:0.82876
# [285]	validation_0-aucpr:0.82860
# [286]	validation_0-aucpr:0.82861
# [287]	validation_0-aucpr:0.82914
# [288]	validation_0-aucpr:0.82863
# [289]	validation_0-aucpr:0.82883
# [290]	validation_0-aucpr:0.82823
# [291]	validation_0-aucpr:0.82836
# [292]	validation_0-aucpr:0.82918
# [293]	validation_0-aucpr:0.82945
# [294]	validation_0-aucpr:0.82933
# [295]	validation_0-aucpr:0.82950
# [296]	validation_0-aucpr:0.82937
# [297]	validation_0-aucpr:0.82939
# [298]	validation_0-aucpr:0.82931
# [299]	validation_0-aucpr:0.82889
# [300]	validation_0-aucpr:0.82888
# [301]	validation_0-aucpr:0.82944
# [302]	validation_0-aucpr:0.82930
# [303]	validation_0-aucpr:0.82918
# [304]	validation_0-aucpr:0.82908
# [305]	validation_0-aucpr:0.82866
# [306]	validation_0-aucpr:0.82847
# [307]	validation_0-aucpr:0.82867
# [308]	validation_0-aucpr:0.82901
# [309]	validation_0-aucpr:0.82891
# [310]	validation_0-aucpr:0.82917
# [311]	validation_0-aucpr:0.82955
# [312]	validation_0-aucpr:0.82944
# [313]	validation_0-aucpr:0.82925
# [314]	validation_0-aucpr:0.82910
# [315]	validation_0-aucpr:0.82898
# [316]	validation_0-aucpr:0.82912
# [317]	validation_0-aucpr:0.82931
# [318]	validation_0-aucpr:0.82892
# [319]	validation_0-aucpr:0.82855
# [320]	validation_0-aucpr:0.82820
# [321]	validation_0-aucpr:0.82817
# [322]	validation_0-aucpr:0.82821
# [323]	validation_0-aucpr:0.82819
# [324]	validation_0-aucpr:0.82815
# [325]	validation_0-aucpr:0.82811
# [326]	validation_0-aucpr:0.82813
# [327]	validation_0-aucpr:0.82821
# [328]	validation_0-aucpr:0.82819
# [329]	validation_0-aucpr:0.82830
# [330]	validation_0-aucpr:0.82849
# [331]	validation_0-aucpr:0.82851
# [332]	validation_0-aucpr:0.82861
# [333]	validation_0-aucpr:0.82858
# [334]	validation_0-aucpr:0.82839
# [335]	validation_0-aucpr:0.82854
# [336]	validation_0-aucpr:0.82845
# [337]	validation_0-aucpr:0.82850
# [338]	validation_0-aucpr:0.82848
# [339]	validation_0-aucpr:0.82848
# [340]	validation_0-aucpr:0.82854
# [341]	validation_0-aucpr:0.82847
# [342]	validation_0-aucpr:0.82864
# [343]	validation_0-aucpr:0.82881
# [344]	validation_0-aucpr:0.82905
# [345]	validation_0-aucpr:0.82899
# [346]	validation_0-aucpr:0.82923
# [347]	validation_0-aucpr:0.82924
# [348]	validation_0-aucpr:0.82871
# [349]	validation_0-aucpr:0.82866
# [350]	validation_0-aucpr:0.82857
# [351]	validation_0-aucpr:0.82855
# [352]	validation_0-aucpr:0.82853
# [353]	validation_0-aucpr:0.82850
# [354]	validation_0-aucpr:0.82840
# [355]	validation_0-aucpr:0.82857
# [356]	validation_0-aucpr:0.82862
# [357]	validation_0-aucpr:0.82860
# [358]	validation_0-aucpr:0.82876
# [359]	validation_0-aucpr:0.82881
# [360]	validation_0-aucpr:0.82885
# [361]	validation_0-aucpr:0.82887
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric='aucpr', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_probs = model.predict_proba(x_test)[:, 1]
y_pred = model.predict(x_test)

print(f"auprc: {average_precision_score(y_test, y_probs)}\n")
print(f"classification report: {classification_report(y_test, y_pred)}")
# Out:
# auprc: 0.8784853524874567
#
# classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.85      0.80      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.90      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model.get_booster().save_model("fraud_model.json")
